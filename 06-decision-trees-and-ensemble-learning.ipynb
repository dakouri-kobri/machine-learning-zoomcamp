# %% [markdown]
# # Homework 6: **Decision Trees and Ensemble Learning**

# %% [markdown]
# ## 1. Import packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2. Load and prepare data
